# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("/kaggle/input/loan-approval-prediction/Training Dataset.csv")
df.head()

# %%
df['Dependents'].value_counts()

# %%
df.columns

# %%
df.info()

# %%
df['Education'].value_counts()

# %%
df.describe()

# %%
df.isna().sum()

# %%
l=df.dtypes
print(l)

# %%
df.head(1)

# %%
df['LoanAmount'].fillna(df['LoanAmount'].mean(),inplace=True)
df['Self_Employed'].fillna('No',inplace=True)
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
df['Married'].fillna(df['Married'].mode()[0], inplace=True)
df['Dependents'].fillna(df['Dependents'].mode()[0], inplace=True)
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0], inplace=True)
df['Credit_History'].fillna(df['Credit_History'].mode()[0], inplace=True)

# %%
df.isnull().sum()

# %%
p={}
for i in df.columns:
    p[i]=df[i].nunique()
print(p)

# %%
df.drop(['Loan_ID'],axis=1,inplace=True)
df

# %%
l=df['Gender'].value_counts()
print(l)

# %%
q=df.dtypes
print(q)

# %%
cc = df.select_dtypes(include='object').columns.tolist()
print(cc)

# %%
plt.figure(figsize=(10, 10))
i=1
for col in cc:
    plt.subplot(3,3,i)
    sns.countplot(x=col,data=df)
    i=i+1

# %%
plt.figure(figsize=(10, 10))
i=1
for col in cc:
    if col=='Loan_Status':
        continue
    else:
        plt.subplot(3,3,i)
        sns.countplot(x=col,hue='Loan_Status',data=df)
        i=i+1

# %%
nc = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
print(nc)

# %%
df['Total_Income']=df['ApplicantIncome']+ df['CoapplicantIncome']
df.head()

# %%
df.drop(['Total_Income'],axis=1,inplace=True)

# %%
plt.figure(figsize=(10, 10))
i=1
for col in nc:
    plt.subplot(3,2,i)
    sns.distplot(df[col],hist=False)
    i=i+1

# %%
Gender=pd.crosstab(df['Gender'],df['Loan_Status'], normalize='index') * 100

Gender

# %%
Gender.plot(kind='bar', stacked=False, figsize=(8, 6))

# %%
t=df.groupby('Loan_Status')['ApplicantIncome'].mean()
print(t)
print(t.plot.bar())

# %%
df.head()

# %%
df.dtypes

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for col in cc:
    df[col]=label_encoder.fit_transform(df[col])
    print(df[col])

# %%
df.dtypes

# %%
for col in cc:
    df[col]=pd.to_numeric(df[col])

# %%
df.dtypes

# %%
df.head(5)

# %%
df.dtypes

# %%
df['Dependents'].value_counts()

# %%
df.dtypes

# %%
plt.figure(figsize=(10,10))
corr=df.corr()
sns.heatmap(corr,square=True, annot = True,fmt='.2f')

# %%
import sklearn
print("scikit-learn version:", sklearn.__version__)

# %%
from sklearn.model_selection import train_test_split
x = df.drop(['Loan_Status'],axis='columns')
y = df.Loan_Status

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
  
knn = KNeighborsClassifier(n_neighbors=3)
rfc = RandomForestClassifier(n_estimators = 7,
                             criterion = 'entropy',
                             random_state =7)
svc = SVC()
lc = LogisticRegression()
for clf in (rfc, knn, svc,lc):
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    print("Accuracy score of ",
          clf.__class__.__name__,
          "=",100*metrics.accuracy_score(y_test, 
                                         y_pred))

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
l = LogisticRegression()
l.fit(x_train, y_train)
y_pred = l.predict(x_test)
print("Accuracy Score :", accuracy_score(y_test, y_pred)*100, "%")

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, y_pred)
print(cm)

# %%
sns.heatmap(cm, annot=True, annot_kws={"size": 30}, fmt='d',cmap="Blues")

# %%
l.predict([[1,0,0,0,0,5849,0.0,146.412162,360.0,1.0,2]])

# %%
l.predict(np.array([[1,0,0,0,0,5849,0.0,146.412162,360.0,1.0,2]]))

# %%
import joblib

# %%
import joblib
joblib.dump(l,'lmodel_filename.joblib')
